# %%
"""
Created on Fri March 29th 
    
    Creating standartized plots
    Plotting templates for various plots
    


@author: weil_tb
"""

# import functions and libs
# %run 00_functions.ipynb

# %% [markdown]
# ## Import

# %%
# Load Data 
# raw Data:
s1_imu_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_imu_raw.npz')
s1_adc_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_adc_raw.npz')
s2_imu_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_imu_raw.npz')
s2_adc_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_adc_raw.npz')
s3_imu_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_imu_raw.npz')
s3_adc_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_adc_raw.npz')
s4_imu_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_imu_raw.npz')
s4_adc_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_adc_raw.npz')
s5_imu_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_imu_raw.npz')
s5_adc_raw = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_adc_raw.npz')

# Load Filtered Data
s1_imu_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_imu_f.npz')
s1_adc_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_adc_f.npz')
s2_imu_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_imu_f.npz')
s2_adc_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_adc_f.npz')
s3_imu_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_imu_f.npz')
s3_adc_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_adc_f.npz')
s4_imu_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_imu_f.npz')
s4_adc_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_adc_f.npz')
s5_imu_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_imu_f.npz')
s5_adc_f = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_adc_f.npz')

# Preprocessed Data:
s1_imu = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_imu_pp.npz')
s1_adc = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s1_adc_pp.npz')
s2_imu = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_imu_pp.npz')
s2_adc = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s2_adc_pp.npz')
s3_imu = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_imu_pp.npz')
s3_adc = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s3_adc_pp.npz')
s4_imu = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_imu_pp.npz')
s4_adc = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s4_adc_pp.npz')
s5_imu = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_imu_pp.npz')
s5_adc = load_npz(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\SparseArray/s5_adc_pp.npz')

# %%
# Load Data Overview
ov = pd.read_csv(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\03_Tables/Data_Overview.csv')
ov.drop(index = ov[ov['Journey'] == 'journey_43'].index,inplace=True)
del ov['Unnamed: 0']
ov
# Out:
#     Session     Journey  Duration_IMU  Valid_Samples_IMU  Min_IMU  Max_IMU  \
# 0        s1  journey_00         71.01               7101  -1.2807   1.2629
# 1        s1  journey_01         39.90               3990  -0.8633   0.6016
# 2        s1  journey_02        111.00              11100  -1.3264   0.8133
# 3        s1  journey_03         39.90               3990  -1.4238   1.2932
# 4        s1  journey_04         59.99               5999  -0.9995   1.4562
# ..      ...         ...           ...                ...      ...      ...
# 131      s5  journey_17         59.00               5900  -0.9953   0.7972
# 132      s5  journey_18         39.94               3994  -0.9070   0.7239
# 133      s5  journey_19         47.98               4798  -1.0623   1.3416
# 134      s5  journey_20         39.07               3907  -0.6213   0.6262
# 135      s5  journey_21         82.06               8206  -0.7277   1.0498
#
# ...

# %%
# Load Data Rating

rat = pd.read_csv(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data/Data_Rating.csv', sep = ';', header = None )
rat.columns = ['Session','Journey', 'Rating']
rat
# Out:
#     Session     Journey Rating
# 0        s1  journey_00      B
# 1        s1  journey_01      C
# 2        s1  journey_02      B
# 3        s1  journey_03      B
# 4        s1  journey_04      C
# ..      ...         ...    ...
# 131      s5  journey_17      C
# 132      s5  journey_18      B
# 133      s5  journey_19      C
# 134      s5  journey_20      B
# 135      s5  journey_21      B
#
# [136 rows x 3 columns]

# %%
# Plot Figure: Journey Length Distribution
plt.style.use(['seaborn-v0_8-paper'])
plt.bar(range(len(ov.Duration_IMU)),ov.Duration_IMU)
plt.xlabel('Journey Nr.', fontsize=12)
plt.ylabel('Duration in [s]', fontsize=12)
# Out:
# Text(0, 0.5, 'Duration in [s]')

# %% [markdown]
# ### Some Metrics ..
# #### DTW

# %%
from tslearn.metrics import dtw, dtw_path

# load random
x = s2_adc_raw[12].data
y = s2_imu_raw[12].data

x_p = s2_adc[12].data
y_p = s2_imu[12].data

dtw_score = dtw(x, y)
dtw_score_p = dtw(x_p, y_p)
# Or, if the path is also an important information:
optimal_path, dtw_score = dtw_path(x, y)

print(dtw_score)
print(dtw_score_p)
# Out:
# 190.1299990113854
# 95.50151419904856

# %%
# plot DTW path for prepocessed data (from: https://tslearn.readthedocs.io/en/stable/auto_examples/metrics/plot_dtw.html#sphx-glr-auto-examples-metrics-plot-dtw-py)

from scipy.spatial.distance import cdist
from tslearn import metrics


s_y1 = x_p.reshape(-1,1)
s_y2 = y_p.reshape(-1,1)
sz = s_y1.shape[0]

path, sim = metrics.dtw_path(s_y1, s_y2)

plt.figure(1, figsize=(8, 8))

# definitions for the axes
left, bottom = 0.01, 0.1
w_ts = h_ts = 0.2
left_h = left + w_ts + 0.02
width = height = 0.65
bottom_h = bottom + height + 0.02

rect_s_y = [left, bottom, w_ts, height]
rect_gram = [left_h, bottom, width, height]
rect_s_x = [left_h, bottom_h, width, h_ts]

ax_gram = plt.axes(rect_gram)
ax_s_x = plt.axes(rect_s_x)
ax_s_y = plt.axes(rect_s_y)

mat = cdist(s_y1, s_y2)

ax_gram.imshow(mat, origin='lower')
ax_gram.axis("off")
ax_gram.autoscale(False)
ax_gram.plot([j for (i, j) in path], [i for (i, j) in path], "w-",
             linewidth=3.)

ax_s_x.plot(np.arange(sz), s_y2, "b-", linewidth=3.)
ax_s_x.axis("off")
ax_s_x.set_xlim((0, sz - 1))

ax_s_y.plot(- s_y1, np.arange(sz), "b-", linewidth=3.)
ax_s_y.axis("off")
ax_s_y.set_ylim((0, sz - 1))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\weil_tb\AppData\Local\Temp\ipykernel_12796\1988965736.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Plot DTW Path for raw Data

x_eq = eq_adc_imu_np(x,y)
s_y1 = x_eq.reshape(-1,1)
s_y2 = y.reshape(-1,1)
sz = s_y1.shape[0]

path, sim = metrics.dtw_path(s_y1, s_y2)

plt.figure(1, figsize=(8, 8))

# definitions for the axes
left, bottom = 0.01, 0.1
w_ts = h_ts = 0.2
left_h = left + w_ts + 0.02
width = height = 0.65
bottom_h = bottom + height + 0.02

rect_s_y = [left, bottom, w_ts, height]
rect_gram = [left_h, bottom, width, height]
rect_s_x = [left_h, bottom_h, width, h_ts]

ax_gram = plt.axes(rect_gram)
ax_s_x = plt.axes(rect_s_x)
ax_s_y = plt.axes(rect_s_y)

mat = cdist(s_y1, s_y2)

ax_gram.imshow(mat, origin='lower')
ax_gram.axis("off")
ax_gram.autoscale(False)
ax_gram.plot([j for (i, j) in path], [i for (i, j) in path], "w-",
             linewidth=3.)

ax_s_x.plot(np.arange(sz), s_y2, "b-", linewidth=3.)
ax_s_x.axis("off")
ax_s_x.set_xlim((0, sz - 1))

ax_s_y.plot(- s_y1, np.arange(sz), "b-", linewidth=3.)
ax_s_y.axis("off")
ax_s_y.set_ylim((0, sz - 1))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\weil_tb\AppData\Local\Temp\ipykernel_12796\1053208718.py:43: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# #### Create Data for Overview table
# Calculate metrics for each journey and save to .csv

# %%
# Session 3 Journey 43 fehlt!
rat.drop(index = rat[rat['Journey'] == 'journey_43'].index,inplace=True)

# %%
# load random
x = s2_adc_raw[3].data
y = s2_imu_raw[3].data

x_p = s3_adc[42].data
y_p = s3_imu[42].data

dtw_score = dtw(x, y)
dtw_score
# Out:
# 114.14400486591988

# %%
# compute cosine similarity
from numpy.linalg import norm
x_eq = eq_adc_imu_np(x,y)
cosine = np.dot(x_eq,y)/(norm(x_eq)*norm(y))
cosine
# Out:
# -0.03181912877246915

# %%
# Calculate fpor all sessions:
DTW1,CrossCorr1,CosSin1 = process_data(s1_adc_raw, s1_imu_raw)
DTW2,CrossCorr2,CosSin2 = process_data(s2_adc_raw, s2_imu_raw)
DTW3,CrossCorr3,CosSin3 = process_data(s3_adc_raw, s3_imu_raw)
DTW4,CrossCorr4,CosSin4 = process_data(s4_adc_raw, s4_imu_raw)
DTW5,CrossCorr5,CosSin5 = process_data(s5_adc_raw, s5_imu_raw)

# %%
# Error handling Session 2 (too long . .  Memory Error
# x = s2_adc_raw[8].data
# y = s2_imu_raw[8].data
# x_eq = eq_adc_imu_np(x,y)

# %%
# Create DF from Lists via dict
# concat lists
DTW = DTW1+DTW2+DTW3+DTW4+DTW5
CrossCorr = CrossCorr1 + CrossCorr2 + CrossCorr3 +CrossCorr4 + CrossCorr5
CosSim = CosSin1 + CosSin2 +CosSin3 +CosSin4 +CosSin5
  
# dictionary of lists 
dict = {'DTW': DTW, 'CrossCorr': CrossCorr, 'CosSim': CosSim} 
    
metrics = pd.DataFrame(dict)

# %%
# correct indices
rat.set_index(metrics.index, inplace=True)
ov.set_index(metrics.index, inplace=True)

ov2 = pd.concat([ov, rat.Rating, metrics], axis = 1)
ov2
#ov2.to_csv(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\03_Tables/Data_Overview_v2.csv')
# Out:
#     Session     Journey  Duration_IMU  Valid_Samples_IMU  Min_IMU  Max_IMU  \
# 0        s1  journey_00         71.01               7101  -1.2807   1.2629
# 1        s1  journey_01         39.90               3990  -0.8633   0.6016
# 2        s1  journey_02        111.00              11100  -1.3264   0.8133
# 3        s1  journey_03         39.90               3990  -1.4238   1.2932
# 4        s1  journey_04         59.99               5999  -0.9995   1.4562
# ..      ...         ...           ...                ...      ...      ...
# 130      s5  journey_17         59.00               5900  -0.9953   0.7972
# 131      s5  journey_18         39.94               3994  -0.9070   0.7239
# 132      s5  journey_19         47.98               4798  -1.0623   1.3416
# 133      s5  journey_20         39.07               3907  -0.6213   0.6262
# 134      s5  journey_21         82.06               8206  -0.7277   1.0498
#
# ...

# %%
# convert Data Rating to numericals
ov2.replace(['A', 'B', 'C'], [1,2,3], inplace=True )
# drop session and journey
corr_matrix = ov2.drop(columns=['Session','Journey']).corr()
plt.imshow(corr_matrix,cmap='hot',interpolation='nearest')
# Out:
# C:\Users\weil_tb\AppData\Local\Temp\ipykernel_19072\2720971160.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ov2.replace(['A', 'B', 'C'], [1,2,3], inplace=True )

# %%
# seaborn version ..
import seaborn as sns
# %matplotlib inline

# plot the heatmap
sns.heatmap(corr_matrix, cmap='bwr')

plt.savefig(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\04_pictures/seaborn_plot.png',bbox_inches = 'tight')

# %% [markdown]
# #### Create PSD Plot for 3.3.1 Bandpass Filter

# %%
adc = s2_adc_raw[12].data
imu = s2_imu_raw[12].data
adc_f = s2_adc[12].data
imu_f = s2_imu[12].data
fig, ax = plt.subplots(1, 1, figsize=(7,4))
ax.psd(imu,Fs=100, label='IMU Signal')
ax.psd(adc,Fs=100, label='ABA Signal')
ax.psd(imu_f,Fs=100, label='IMU Signal filtered')
ax.psd(adc_f,Fs=100, label='ABA Signal filtered')
#ax.plot(x, y, 'o--', color='r', lw=0.4, ms=3)
#ax.text(0.1, 0.1, 'text here', transform=ax.transAxes)
#ax.set_xlabel('Nyquist Frequency = 50 Hz [-]')
#ax.set_ylabel(r'Power Spectral Density [dB/Hz]')
plt.legend()
plt.show()
fig.savefig('04_pictures/Filter_nec.png', dpi=200)
#plt.psd(imu)
#plt.psd(adc)

# %%
plt.psd(imu)
# Out:
# (array([5.69988742e-01, 3.06705161e-01, 4.57828716e-02, 7.22213969e-02,
#         7.50976675e-02, 1.78628627e-01, 1.25260713e+00, 1.29547187e+00,
#         2.29938655e-01, 7.90049513e-02, 6.30252766e-02, 4.23112539e-02,
#         2.99249283e-02, 4.64176623e-02, 5.16047271e-02, 2.44677685e-02,
#         2.39868459e-02, 2.03968283e-02, 1.31252933e-02, 9.05179386e-03,
#         7.31803832e-03, 9.60800265e-03, 9.09085720e-03, 9.53354462e-03,
#         9.93965292e-03, 9.25066305e-03, 7.62816908e-03, 8.16450151e-03,
#         1.02267908e-02, 1.02332379e-02, 1.36154297e-02, 1.54114749e-02,
#         2.18505459e-02, 3.34766238e-02, 3.39672382e-02, 4.24242983e-02,
#         4.35144451e-02, 5.21053637e-02, 4.78903577e-02, 3.53774899e-02,
#         2.31583709e-02, 1.60713730e-02, 1.26754425e-02, 1.21870656e-02,
#         1.13459146e-02, 1.14138326e-02, 7.64707006e-03, 4.17040836e-03,
#         3.53886497e-03, 2.24117051e-03, 1.82679726e-03, 1.99210784e-03,
# ...

# %% [markdown]
# ## Plotting Templates

# %%
########################################## Just exchange journey's to create plot ####################################
# Define Fig for Full Pager with 4 stapled graphs

fig, axes = plt.subplots(4, 1, figsize=(6, 9),layout='constrained')
#fig.tight_layout()
#saved commands

#fig.suptitle('Example Journey', y=1.03, fontsize=15)
#ax.set_title('z-Acc Signal ADC')
#ax.text(0.925, 0.07, '-154.31384', transform=ax.transAxes,fontsize=12)

ax = axes[0]
ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc1, label='ABA Signal (1)',lw=0.5, color='tab:blue')
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration in [$m/s^2$]')



ax = axes[1]
ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc2, label='ABA Signal (2)', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration in [$m/s^2$]')


ax = axes[2]
ax.grid('minor')
ax.set_ylim(-2.5, 2.5) #  set limits to axes
ax.plot(imu, label='IMU Signal', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration in [$m/s^2$]')


ax = axes[3]
ax.grid('minor')
#ax.yaxis.set_label_position("right")
#ax.yaxis.tick_right()
ax.set_ylim(-0, 6) #  set limits to axes
ax.plot(speed, label='Speed Signal', color='tab:blue',lw=0.8)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('speed in [$km/h$]')

fig.align_labels()

# %%
# Define Fig for half Pager with 2 stapled graphs
fig, axes = plt.subplots(2, 1, figsize=(6, 4.5),layout='constrained')

#saved commands
#fig.tight_layout()
#fig.suptitle('Example Journey', y=1.03, fontsize=15)
#ax.set_title('z-Acc Signal ADC')
#ax.text(0.925, 0.07, '-154.31384', transform=ax.transAxes,fontsize=12)

ax = axes[0]
ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc1, label='ABA Signal (1)', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration in [$m/s^2$]')



ax = axes[1]
ax.grid('minor')
ax.yaxis.set_label_position("right")
ax.yaxis.tick_right()
ax.set_ylim(-0, 6) #  set limits to axes
ax.plot(speed, label='Speed Signal', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('speed in [$km/h$]')
fig.align_labels()

# %%
## Standard Plot for Quadrat 

fig, ax = plt.subplots(1, 1, figsize=(4, 4),layout='constrained')

#saved commands
#fig.tight_layout()
#fig.suptitle('Example Journey', y=1.03, fontsize=15)
#ax.set_title('z-Acc Signal ADC')
#ax.text(0.925, 0.07, '-154.31384', transform=ax.transAxes,fontsize=12)

ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc1, label='ABA Signal (1)', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration in [$m/s^2$]')
ax.set_xlabel('time in [$s$]')

# %% [markdown]
# ## Create Standardtized Plots for Thesis

# %% [markdown]
# #### Fig 10 & 16

# %%
# # Create Fig 10: hyperbolic tangent

# x = np.linspace(-2,2,200)
# y = np.tanh(x)

# fig, ax = plt.subplots(1, 1, figsize=(4, 3.5),layout='constrained')

# #saved commands
# #fig.tight_layout()
# #fig.suptitle('Example Journey', y=1.03, fontsize=15)
# #ax.set_title('z-Acc Signal ADC')
# #ax.text(0.925, 0.07, '-154.31384', transform=ax.transAxes,fontsize=12)

# ax.grid('minor')
# #ax.set_ylim(-250, 250) #  set limits to axes
# ax.plot(x,y, label='Hyperbolic tangent', color='tab:blue',lw=1)
# ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
# #ax.set_xlabel('Frequency [Hz]')
# #ax.set_ylabel(r'Power Spectral Density [dB/Hz]')
# #fig.savefig('04_pictures/tanh.png', dpi=200)

# # Create Fig 16: Distribution Journey Length

# fig, ax = plt.subplots(1, 1, figsize=(4, 3.5),layout='constrained')

# #saved commands
# #fig.tight_layout()
# #fig.suptitle('Example Journey', y=1.03, fontsize=15)
# #ax.set_title('z-Acc Signal ADC')
# #ax.text(0.925, 0.07, '-154.31384', transform=ax.transAxes,fontsize=12)

# ax.grid('minor')
# #ax.set_ylim(-250, 250) #  set limits to axes
# plt.bar(range(len(ov.Duration_IMU)),ov.Duration_IMU,color='tab:blue')
# #ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
# plt.xlabel('Journey Nr.')
# plt.ylabel('Duration in [s]')

# %% [markdown]
# #### Fig 17

# %%
f = h5py.File(r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020061711513200456_20230210_153927.h5" , 'r')
f.keys()
jrn = 'journey_02'
adc1 = f[jrn]['ADC1']['data_ADC1']['ch0']
speed = f[jrn]['ADC1']['data_ADC1']['speed']
adc2 = f[jrn]['ADC2']['data_ADC2']['ch0']
imu = f[jrn]['IMU']['data_IMU']['acc_z']

fig, axes = plt.subplots(4, 1, figsize=(6, 9),layout='constrained')

ax = axes[0]
ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc1, label='ABA Signal (1)',lw=0.5, color='tab:blue')
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('acceleration [$m/s^2$]')



ax = axes[1]
ax.grid('minor')
ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(adc2, label='ABA Signal (2)', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration [$m/s^2$]')


ax = axes[2]
ax.grid('minor')
ax.set_ylim(-2.5, 2.5) #  set limits to axes
ax.plot(imu, label='IMU Signal', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration [$m/s^2$]')


ax = axes[3]
ax.grid('minor')
#ax.yaxis.set_label_position("right")
#ax.yaxis.tick_right()
ax.set_ylim(-0, 6) #  set limits to axes
ax.plot(speed, label='Speed Signal', color='tab:blue',lw=0.8)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('speed [$km/h$]')
ax.set_xlabel('samples [-]')
fig.align_labels()

# %% [markdown]
# #### Fig 18

# %%
jrn = 4
aba = s1_adc[jrn].data
imu = s1_imu[jrn].data

# Define Fig for half Pager with 2 stapled graphs
fig, axes = plt.subplots(2, 1, figsize=(6, 4.5),layout='constrained')

ax = axes[0]
ax.grid('minor')
#ax.set_ylim(-250, 250) #  set limits to axes
ax.plot(aba, label='ABA Signal', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_ylabel('acceleration [$m/s^2$]')

ax = axes[1]
ax.grid('minor')
ax.plot(imu, label='IMU Signal', color='tab:blue',lw=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('acceleration [$m/s^2$]')
ax.set_xlabel('samples [-]')
fig.align_labels()

# %% [markdown]
# #### Fig 20

# %%
adc = s2_adc_raw[12].data
imu = s2_imu_raw[12].data
adc_f = s2_adc[12].data
imu_f = s2_imu[12].data

fig, ax = plt.subplots(1, 1, figsize=(4, 3.5),layout='constrained')
ax.grid('minor')
ax.psd(imu,Fs=100, label='IMU Signal',color='tab:blue')
ax.psd(imu_f,Fs=100, label='IMU Signal filtered',color='tab:green')
ax.psd(adc,Fs=100, label='ABA Signal',color='tab:red')
ax.psd(adc_f,Fs=100, label='ABA Signal filtered',color='tab:orange')
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc=0)
ax.set_xlabel('Frequency [$Hz$]')
ax.set_ylabel(r'Power Spectral Density [$dB/Hz$]')

# %% [markdown]
# #### Fig 21

# %%
jrn = 4
aba = s1_adc[jrn].data
imu = s1_imu[jrn].data

# Define Fig for half Pager with 2 stapled graphs
fig, axes = plt.subplots(2, 1, figsize=(6, 4.5),layout='constrained')

ax = axes[0]
ax.grid('minor')
ax.set_ylim(-25, 25) #  set limits to axes
ax.plot(s2_adc_raw[12].data, label='ABA org.',color='tab:blue',linewidth=0.5)
ax.plot(s2_adc_f[12].data, label='ABA filt.',color='tab:orange',linewidth=0.5)
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('acceleration [$m/s^2$]')

ax = axes[1]
ax.grid('minor')
#ax.yaxis.set_label_position("right")
#ax.yaxis.tick_right()
ax.set_ylim(-2, 2) #  set limits to axes
ax.plot(s2_imu_raw[12].data, label='IMU org.',linewidth=0.5, color ='tab:blue')
ax.plot(s2_imu_f[12].data, label='IMU filt.',linewidth=0.5, color ='tab:orange')
ax.legend(fontsize=10, fancybox=False, edgecolor='black',loc='upper right')
ax.set_ylabel('acceleration [$m/s^2$]')
ax.set_xlabel('samples [-]')
fig.align_labels()

# %% [markdown]
# #### Fig 24 -> in 05_NN // Fig 25 in 06_CNN
