# %%
"""
Created on Wed January 17th 
    
    Extract Data from .h5 files 
    save as sparse arrays
    create data overview


@author: weil_tb
"""


# import functions and libs
# %run 00_functions.ipynb

# %% [markdown]
# #### Load Data

# %%
### Load Data from .h5 Files
#Run Once: takes forever -> Load and Save data locally as .npy arrays

# Data paths
path1 = r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2019092305093500214_20230210_111052.h5" # (3,4 Gb)
path2 = r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020012414325300287_20230210_115111.h5" # (6,2 Gb)
path3 = r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020061607581100435_20230210_153528.h5" # (8,1 Gb)
#path4 = r"‪\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020061710464800450_20230210_153913.h5" # (0,2 Gb) <--- corrupted
#path5 = r"‪\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020061710592000451_20230210_153921.h5" # (0,2 Gb) <--- corrupted
path4 = r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2020061711513200456_20230210_153927.h5" # (8,9 Gb)
path5 = r"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\data_geo_2021010809212801010_20230210_163215.h5" # (8,9 Gb)


"""
    Direct access:
    f1['journey_00']['ADC2']['data_ADC2']['ch0']
    f1['journey_00']['IMU']['data_IMU']['acc_z']

    Helpful:
    f['journey_05']['IMU']['data_IMU'].dtype.names
"""
# Out:
# "\n    Direct access:\n    f1['journey_00']['ADC2']['data_ADC2']['ch0']\n    f1['journey_00']['IMU']['data_IMU']['acc_z']\n\n    Helpful:\n    f['journey_05']['IMU']['data_IMU'].dtype.names\n"

# %%
# Read files
f1 = h5py.File(path1, 'r')
f2 = h5py.File(path2, 'r')
f3 = h5py.File(path3, 'r')
f4 = h5py.File(path4, 'r')
f5 = h5py.File(path5, 'r')

f_list = [f1, f2, f3, f4, f5]
Data_Overview = pd.DataFrame()

# %%
# #Run Once: takes forever -> Load and Save data locally as .npy arrays & Create Data_overview table 

# cnt = 0
# for f in f_list:
#     cnt+=1
#     jrn_list = list(f.keys())
#     for jrn in tqdm(jrn_list):
#         #skip those -> Errors as they are corrupted
#         if f == f5 and jrn == ('journey_00'):
#             continue
#         if f == f5 and jrn == ('journey_01'):
#             continue
#         #save orginal ABA Data
#         adc_org = f[jrn]['ADC2']['data_ADC2']['ch0']
#         np.save(rf"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight\s{cnt}_{jrn}_ADC_og", adc_org)
#         # Resample to IMU Frequency 20625 Hz to 100 Hz and save
#         adc = scipy.signal.resample_poly(adc_org, 100 , 20625, axis=0, window=('tukey'), padtype='constant', cval=None)
#         np.save(rf"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight\s{cnt}_{jrn}_ADC", adc)
#         # Save IMU Data for all 3 dimensions
#         imu_z = f[jrn]['IMU']['data_IMU']['acc_z']
#         imu_x = f[jrn]['IMU']['data_IMU']['acc_x']
#         imu_y = f[jrn]['IMU']['data_IMU']['acc_y']
#         np.save(rf"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight\s{cnt}_{jrn}_imu_z", imu_z)
#         np.save(rf"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight\s{cnt}_{jrn}_imu_z", imu_x)
#         np.save(rf"\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight\s{cnt}_{jrn}_imu_z", imu_y)
#         # Create new row for data_overview
#         new_row = pd.DataFrame.from_records([{
#             'Session': str(f),
#             'Journey': str(jrn),
#             'Duration_IMU' : imu_z.size/100,
#             #'Valid_Samples_IMU' : np.count_nonzero(imu),
#             'Min_IMU' : imu_z.min(),
#             'Max_IMU' : imu_z.max(),
#             'Mean_IMU' : imu_z.mean(),
#             'Std_IMU' : imu_z.std(),
#             'Duration_ADC' : adc.size/100,
#             #'Valid_Samples_ADC' : np.count_nonzero(adc),
#             'Min_ADC' : adc.min(),
#             'Max_ADC' : adc.max(),
#             'Mean_ADC' : adc.mean(),
#             'Std_ADC' : adc.std()}])
#     # concat data overview
#     Data_Overview = pd.concat([Data_Overview, new_row])

# Data_Overview.to_csv('\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data.csv')
# Data_Overview

# %% [markdown]
# #### Visualize some data and first filter apporaches

# %%
# Process Data
adc = scipy.signal.resample_poly(f1['journey_00']['ADC2']['data_ADC2']['ch0'],100 , 20625, axis=0, window=('tukey'), padtype='constant', cval=None)
imu_z =  f1['journey_00']['IMU']['data_IMU']['acc_z']
imu_x =  f1['journey_00']['IMU']['data_IMU']['acc_x']
imu_y =  f1['journey_00']['IMU']['data_IMU']['acc_y']

lowcut = 1
highcut_adc = 25
highcut_imu = 5
fs = 100

adc_filt = butter_bandpass_filter(adc, lowcut, highcut_adc, fs, order=2)
imu_filt = butter_bandpass_filter(imu, lowcut, highcut_imu, fs, order=2)


scaler_adc = StandardScaler().fit(adc_filt)
adc_sc = scaler_adc.transform(scaler_adc)

scaler_imu = StandardScaler().fit(imu_filt)
imu_sc = scaler_imu.transform(scaler_imu)

# %%
# Plot Data
fig, axes = plt.subplots(2, 1, figsize=(18,10))
fig.tight_layout()
fig.suptitle('journey_00', y=1.03, fontsize=25)
ax = axes[0]
ax.plot(adc[2000:4000], label='adc')
ax.plot(adc_filt[2000:4000], label='adc_filt')
ax.legend()
ax = axes[1]
ax.plot(imu[2000:4000], label='imu')
ax.plot(imu_filt[2000:4000], label='imu_filt')
ax.legend()

# %% [markdown]
# #### Multiplicative and additive decomposition

# %%
# Try: Multiplicative and additive decomposition of signals : turns out it's useless and can be replaced by filtering

# from statsmodels.tsa.seasonal import seasonal_decompose
# from dateutil.parser import parse

# multiplicative_decomposition = seasonal_decompose(adc+20, model='multiplicative', period=30)

# # Additive Decomposition
# additive_decomposition = seasonal_decompose(adc+20, model='additive', period=30)

# # Plot
# plt.rcParams.update({'figure.figsize': (16,12)})
# multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize=16)
# plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
# plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# plt.show()

# %% [markdown]
# #### Create Data Overview

# %%
# create list containing all data file names
path = r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight'
data_list = os.listdir(path)
del data_list[0] # deleting first element as it's a folder
imu_z =  np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_imu_z.npy')

# %%
# re Create Data Overview as it didn't work
data_overview = pd.DataFrame()

# iterating through all journeys (folder contains 5 files per journey: adc, adc_og, imu_x, imu_y, imu_z)
for i in range(int(len(data_list)/5)):
    #Load ADC and IMU Data    
    imu_z =  np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/'+ data_list[(i*5)+4])
    adc = np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/'+ data_list[i*5])
    
    # Get List with Session and Journey Nr
    list = data_list[i*5].split('_')
    session = list[0]

    # Create new row for data_overview
    new_row = pd.DataFrame.from_records([{
                'Session': list[0],
                'Journey': 'journey_' + list[2],
                'Duration_IMU' : imu_z.size/100,
                'Valid_Samples_IMU' : np.count_nonzero(imu_z),
                'Min_IMU' : np.round(imu_z.min(),4),
                'Max_IMU' : np.round(imu_z.max(),4),
                'Mean_IMU' : np.round(imu_z.mean(),4),
                'Std_IMU' : np.round(imu_z.std(),4),
                'Duration_ADC' : adc.size/100,
                'Valid_Samples_ADC' : np.count_nonzero(adc),
                'Min_ADC' : np.round(adc.min(),4),
                'Max_ADC' : np.round(adc.max(),4),
                'Mean_ADC' : np.round(adc.mean(),4),
                'Std_ADC' : np.round(adc.std(),4)}])

    data_overview = pd.concat([data_overview, new_row])
data_overview

# %%
    #write data
data_overview.to_csv("Data_Overview.csv")

# %% [markdown]
# #### Create sparse arrays
# for each session .npz from .npy arrays
# - s1:  15 * 28504
# - s2: 18 * 60894
# - s3: 43 * 16008
# - s4: 39 * 28304
# - s5: 20 journey * max 15904

# %%
# Test sparse
# mx = maximal length of a journey 
mx = 28504
r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_imu_z.npy'
x = pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_imu_z.npy'),mx)
xx = pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_ADC.npy'),mx)
y = pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_01_imu_z.npy'),mx)
yy = pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_01_ADC.npy'),mx)

# %%
# Session 1 
mx = 28504
# create a list to then create a sparse array from it! Best way to ceate and store sparse arrays
arr_imu1 = np.array([pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_01_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_02_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_03_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_04_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_05_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_06_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_07_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_08_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_09_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_10_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_11_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_12_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_13_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_14_imu_z.npy'),mx)])

arr_adc1 = np.array([pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_00_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_01_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_02_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_03_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_04_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_05_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_06_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_07_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_08_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_09_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_10_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_11_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_12_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_13_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s1_journey_14_ADC.npy'),mx)])

# create sparse element
s1_imu = csr_matrix(arr_imu1)
s1_adc = csr_matrix(arr_adc1)

# Session 2#
mx = 60894
arr_imu2 = np.array([pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_00_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_01_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_02_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_03_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_04_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_05_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_06_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_07_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_08_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_09_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_10_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_11_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_12_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_13_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_14_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_15_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_16_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_17_imu_z.npy'),mx),
               ])


arr_adc2 = np.array([pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_00_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_01_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_02_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_03_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_04_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_05_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_06_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_07_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_08_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_09_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_10_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_11_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_12_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_13_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_14_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_15_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_16_ADC.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s2_journey_17_ADC.npy'),mx),])

s2_imu = csr_matrix(arr_imu2)
s2_adc = csr_matrix(arr_adc2)

# Session 3
mx = 16008
arr_imu3 = np.array([pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey_00_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey_01_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey_02_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey_03_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey_04_imu_z.npy'),mx),
                pad_zero(np.load(r'\\bstsfs02.intra.dlr.de\AIMunsicher02\Trackscan\Studenten_2023_04\Masterarbeit_Weiland\Data\Data_Overnight/s3_journey